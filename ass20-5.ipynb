# %% [markdown]
# <a href="https://colab.research.google.com/github/Geethika1205/Ai-asisstant/blob/main/ass20-5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bcrypt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 3.5 MB/s eta 0:00:00
# ...

# %%
import bcrypt

users = {}

def register():
    username = input("Enter username: ")
    password = input("Enter password: ").encode('utf-8')

    # Hash the password
    hashed = bcrypt.hashpw(password, bcrypt.gensalt())

    users[username] = hashed
    print("User registered successfully (password hashed)!")

def login():
    username = input("Enter username: ")
    password = input("Enter password: ").encode('utf-8')

    if username in users:
        stored_hash = users[username]

        # Verify password
        if bcrypt.checkpw(password, stored_hash):
            print("Login successful!")
        else:
            print("Invalid password")
    else:
        print("User not found")

# Test
register()
login()
# Out:
# Enter username: geethika
# Enter password: 123456
# User registered successfully (password hashed)!
# Enter username: geethika123
# Enter password: 123456
# User not found

# %%
pip install python-dotenv

# %%
import os

os.environ["API_KEY"] = "your_real_key_here"

# %%
from dotenv import load_dotenv
import os

load_dotenv()

API_KEY = os.getenv("API_KEY")
print(API_KEY)
# Out:
# your_real_key_here

# %%
from dotenv import load_dotenv
import os
import requests

load_dotenv()

API_KEY = os.getenv("API_KEY")

def get_weather(city):
    url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={API_KEY}"
    response = requests.get(url)

    return response.json()

data = get_weather("Chennai")

print(data)
# Out:
# {'cod': 401, 'message': 'Invalid API key. Please see https://openweathermap.org/faq#error401 for more info.'}

# %%
import subprocess
import re

filename = input("Enter filename: ")

# Allow only safe filenames (letters, numbers, ., _)
if not re.match(r'^[\w.\-]+$', filename):
    print("Invalid filename!")
else:
    result = subprocess.run(["ls", filename], capture_output=True, text=True)
    print(result.stdout)
# Out:
# Enter filename: geet

# %%
# Enhanced Student Grade Calculator

def calculate_grade(avg):
    if avg >= 90:
        return "A"
    elif avg >= 75:
        return "B"
    elif avg >= 50:
        return "C"
    else:
        return "Fail"

name = input("Enter student name: ")

marks = []
subjects = int(input("Enter number of subjects: "))

for i in range(subjects):
    while True:
        try:
            m = float(input(f"Enter marks for subject {i+1}: "))
            if 0 <= m <= 100:
                marks.append(m)
                break
            else:
                print("Marks should be between 0 and 100")
        except ValueError:
            print("Invalid input! Enter numeric value.")

average = sum(marks) / subjects
grade = calculate_grade(average)

print("\n--- Result ---")
print("Name:", name)
print("Average:", round(average, 2))
print("Grade:", grade)
# Out:
# Enter student name: geeth
# Enter number of subjects: 5
# Enter marks for subject 1: 60
# Enter marks for subject 2: 75
# Enter marks for subject 3: 88
# Enter marks for subject 4: 79
# Enter marks for subject 5: 68
#
# --- Result ---
# Name: geeth
# Average: 74.0
# Grade: C
